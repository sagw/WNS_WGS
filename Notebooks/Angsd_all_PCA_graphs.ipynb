# %%
#covariance matrix created with PCANGSD python /local/home/sarahgw/pcangsd/pcangsd.py -beagle /local/home/sarahgw/WGS/SNPS/All_mylu/genolike/All_mylu_gl_filt.beagle.gz -n 132 -o /local/home/sarahgw/WGS/SNPS/All_mylu/genolike/All_mylu_gl_filt -threads 10

# %%
setwd("/local/home/sarahgw/WGS/SNPS/All_mylu/genolike/")
samples=read.table("/local/home/sarahgw/WGS/Sequences/filelists/All_Mylu.filelist", header=FALSE)

# %%
samples1=gsub("_pairedplus_marked_dupes.bam", " ", samples$V1)

# %%
print(samples1)
# Out:
#   [1] "NJ_E_01 " "NJ_E_02 " "NJ_E_04 " "NJ_E_23 " "NJ_E_24 " "NJ_E_25 "
#   [7] "NJ_E_26 " "NJ_E_28 " "NJ_E_29 " "NJ_E_30 " "NJ_E_05 " "NJ_E_06 "
#  [13] "NJ_E_07 " "NJ_E_08 " "NJ_E_10 " "NJ_E_22 " "NJ_E_13 " "NJ_E_14 "
#  [19] "NJ_E_15 " "NJ_E_16 " "NJ_E_18 " "NJ_E_21 " "NJ_U_01 " "NJ_U_02 "
#  [25] "NJ_U_03 " "NJ_U_05 " "NJ_U_06 " "NJ_U_08 " "NJ_U_09 " "NJ_U_10 "
#  [31] "NJ_U_11 " "NJ_U_12 " "NJ_U_15 " "NJ_U_16 " "NJ_U_21 " "NJ_U_22 "
#  [37] "NJ_U_23 " "NJ_U_25 " "NJ_U_07 " "NJ_U_17 " "NJ_U_18 " "NJ_U_19 "
#  [43] "NY_E_15 " "NY_E_16 " "NY_E_17 " "NY_E_18 " "NY_E_27 " "NY_E_28 "
#  [49] "NY_E_29 " "NY_E_30 " "NY_E_19 " "NY_E_21 " "NY_E_22 " "NY_E_23 "
#  [55] "NY_E_25 " "NY_E_03 " "NY_E_04 " "NY_E_05 " "NY_E_06 " "NY_E_07 "
#  [61] "NY_E_08 " "NY_E_09 " "NY_E_10 " "NY_U_10 " "NY_U_11 " "NY_U_12 "
#  [67] "NY_U_14 " "NY_U_15 " "NY_U_16 " "NY_U_18 " "NY_U_19 " "NY_U_21 "
#  [73] "NY_U_23 " "NY_U_25 " "NY_U_26 " "NY_U_27 " "NY_U_28 " "NY_U_30 "
# ...

# %%
pops=rep(c("Hibernia_Post","Hibernia_Pre", "Williams_Post", "Williams_Pre", "Aeolus_Post", "Greeley_Pre"), times=c(22, 20, 21, 22, 27, 20))
popcols=rep(c("darkblue","darkblue", "cornflowerblue", "cornflowerblue", "darkcyan", "cyan3"), times=c(22, 20, 21, 22, 27, 20))
time=rep(c(0,2, 0, 2, 0, 2), times=c(22, 20, 21, 22, 27, 20))

# %%
pops_noout=rep(c("Hibernia_Post","Hibernia_Pre", "Williams_Post", "Williams_Pre", "Aeolus_Post", "Greeley_Pre"), times=c(22, 20, 19, 22, 27, 18))
popcols_noout=rep(c("darkblue","darkblue", "cornflowerblue", "cornflowerblue", "darkcyan", "cyan3"), times=c(22, 20, 19, 22, 27, 18))
time_noout=rep(c(0,2, 0, 2, 0, 2), times=c(22, 20, 19, 22, 27, 18))

# %%
cov_noout=cov[, -c(130, 124, 70, 64)]
cov_noout=cov_noout[-c( 130, 124, 70, 64),]

# %%
cov_noout=cov[, -c(130, 124)]
cov_noout=cov_noout[-c(130, 124  ),]

# %%
NROW(cov_noout)
NCOL(cov_noout)
# Out:
# [1] 130
# [1] 130

# %%
head(cov_noout)
# Out:
#      V1            V2            V3            V4            V5
# [1,]  1.000047e+00  2.756236e-06 -1.275698e-06 -2.158916e-06 -4.410113e-06
# [2,]  2.756236e-06  1.014250e+00 -1.394802e-03 -2.640088e-03 -2.768387e-03
# [3,] -1.275698e-06 -1.394802e-03  1.006741e+00 -2.048380e-03 -2.176967e-03
# [4,] -2.158916e-06 -2.640088e-03 -2.048380e-03  1.022779e+00 -5.098422e-03
# [5,] -4.410113e-06 -2.768387e-03 -2.176967e-03 -5.098422e-03  1.020344e+00
# [6,] -3.732546e-06 -1.287058e-03 -1.255207e-03 -1.057438e-03 -2.901288e-03
#      V6            V7            V8            V9            V10           ⋯
# [1,] -3.732546e-06 -5.581148e-06 -2.145642e-06 -3.126555e-06 -4.363561e-06 ⋯
# [2,] -1.287058e-03 -3.706499e-03 -1.453925e-03 -1.153464e-03 -2.759747e-03 ⋯
# [3,] -1.255207e-03 -3.001704e-03 -9.799586e-04 -9.410879e-04 -2.228798e-03 ⋯
# [4,] -1.057438e-03 -3.989324e-03 -1.809878e-03 -1.550047e-03 -3.717995e-03 ⋯
# ...

# %%
e = eigen(cov_noout)
#pdf("/local/home/sarahgw/WGS/SNPS/All_mylu/plots/PCA_plot_noout.pdf", width = 6, height = 6)
plot(e$vectors[,1:2],lwd=2,ylab="PC 1",xlab="PC 2",main="Principal components",col=popcols, pch=time)
legend(x=-.7, y=0.765, bty="n", pch=c(0, 2),  legend=c("Post", "Pre"), col=c("black","black"), )
legend(x=-.71, y=0.69, bty="n",  lty=1, legend=c("Williams", "Hibernia", "Aeolus", "Greeley"), col=c("darkblue",  "cornflowerblue", "darkcyan", "cyan3"))
#dev.off()
# Out:
# Plot with title “Principal components”

# %%
e = eigen(cov_noout)
#pdf("/local/home/sarahgw/WGS/SNPS/All_mylu/plots/PCA_plot_noout.pdf", width = 6, height = 6)
plot(e$vectors[,1:2],lwd=2,ylab="PC 1",xlab="PC 2",main="Principal components",col=popcols, pch=time)
legend(x=-.7, y=0.765, bty="n", pch=c(0, 2),  legend=c("Post", "Pre"), col=c("black","black"), )
legend(x=-.71, y=0.69, bty="n",  lty=1, legend=c("Williams", "Hibernia", "Aeolus", "Greeley"), col=c("darkblue",  "cornflowerblue", "darkcyan", "cyan3"))
#dev.off()
# Out:
# Plot with title “Principal components”

# %%
26 33 vt

10 18 ny

# %%
head(cov)
# Out:
#      V1            V2            V3            V4            V5
# [1,]  1.000047e+00  2.756236e-06 -1.275698e-06 -2.158916e-06 -4.410113e-06
# [2,]  2.756236e-06  1.014250e+00 -1.394802e-03 -2.640088e-03 -2.768387e-03
# [3,] -1.275698e-06 -1.394802e-03  1.006741e+00 -2.048380e-03 -2.176967e-03
# [4,] -2.158916e-06 -2.640088e-03 -2.048380e-03  1.022779e+00 -5.098422e-03
# [5,] -4.410113e-06 -2.768387e-03 -2.176967e-03 -5.098422e-03  1.020344e+00
# [6,] -3.732546e-06 -1.287058e-03 -1.255207e-03 -1.057438e-03 -2.901288e-03
#      V6            V7            V8            V9            V10           ⋯
# [1,] -3.732546e-06 -5.581148e-06 -2.145642e-06 -3.126555e-06 -4.363561e-06 ⋯
# [2,] -1.287058e-03 -3.706499e-03 -1.453925e-03 -1.153464e-03 -2.759747e-03 ⋯
# [3,] -1.255207e-03 -3.001704e-03 -9.799586e-04 -9.410879e-04 -2.228798e-03 ⋯
# [4,] -1.057438e-03 -3.989324e-03 -1.809878e-03 -1.550047e-03 -3.717995e-03 ⋯
# ...

# %%
cov =as.matrix(read.table("All_mylu_gl_filt_alph.cov"))
e = eigen(cov)

#pdf("/local/home/sarahgw/WGS/SNPS/All_mylu/plots/PCA_plot.pdf", width = 6, height = 6)
plot(e$vectors[,1:2],lwd=2,ylab="PC 1",xlab="PC 2",main="Principal components",col=popcols, pch=time)
legend(x=-.7, y=0.765, bty="n", pch=c(0, 2),  legend=c("Post", "Pre"), col=c("black","black"), )
legend(x="bottom", bty="n",  lty=1, legend=c("Hibernia", "Williams", "Aeolus", "Greeley"), col=c("darkblue",  "cornflowerblue", "darkcyan", "cyan3"))
#dev.off()
# Out:
# Plot with title “Principal components”

# %%
e
# Out:
# eigen() decomposition
# $values
#   [1] 2.5864640 1.1047834 1.0694723 1.0527609 1.0495310 1.0428317 1.0422305
#   [8] 1.0397608 1.0386209 1.0355918 1.0344299 1.0336695 1.0325661 1.0324233
#  [15] 1.0322017 1.0308782 1.0303979 1.0297398 1.0292219 1.0286721 1.0281803
#  [22] 1.0274260 1.0268620 1.0263227 1.0261997 1.0256144 1.0253766 1.0251934
#  [29] 1.0248237 1.0245696 1.0243653 1.0241551 1.0237540 1.0236577 1.0233766
#  [36] 1.0232585 1.0231588 1.0229920 1.0227922 1.0223738 1.0219893 1.0215251
#  [43] 1.0214208 1.0210759 1.0209117 1.0206680 1.0204674 1.0197105 1.0192564
#  [50] 1.0189599 1.0183206 1.0181023 1.0175305 1.0170281 1.0166893 1.0165054
#  [57] 1.0162185 1.0159733 1.0158647 1.0155831 1.0153335 1.0148672 1.0147310
#  [64] 1.0145870 1.0142853 1.0139641 1.0134619 1.0132057 1.0130431 1.0126238
#  [71] 1.0123792 1.0119071 1.0117760 1.0115921 1.0112604 1.0110629 1.0108474
#  [78] 1.0107656 1.0106927 1.0106330 1.0103869 1.0101353 1.0097513 1.0095819
# ...

# %%
length(e$vectors)
# Out:
# [1] 17424

# %%
cov =as.matrix(read.table("All_mylu_gl_filt_alph.cov"))
e = eigen(cov)
plot(e$vectors[,1:2],lwd=2,ylab="PC 1",xlab="PC 2",main="Principal components",col=popcols)
text(e$vectors[,1], e$vectors[,2], pos= 3, cex=0.5, labels=samples1)
# Out:
# Plot with title “Principal components”

# %% [markdown]
# Look at which loci load most strongly on each of the axes
#
# For the outlier loci, is it these six individuals that are driving the changes in allele frequency? do they have unusal genotypes at our loci?
# Is there admixture analyses that I can do to see if there is gene flow between species for these individuals.
#
# ngsAdmix (look at that bee paper)
#
# western long eared bat species complex.

# %% [markdown]
# Look at eigenvectors, if there are certain loci that are driving it,

# %% [markdown]
# Other outliers:
# VTU26- 45%
# VTU33- 62%
# NYU10- ~75%
# NYU18- 70% coverage
# NJU22
# NJU23

# %%
~/angsd/angsd/misc/NGSadmix -likes /local/home/sarahgw/WGS/SNPS/All_mylu/genolike/All_mylu_gl_filt.beagle.gz -K 6 -P 10 -o /local/home/sarahgw/WGS/SNPS/All_mylu/genolike/All_mylu_gl_filt_admix6.2 
~/angsd/angsd/misc/NGSadmix -likes /local/home/sarahgw/WGS/SNPS/All_mylu/genolike/All_mylu_gl_filt.beagle.gz -K 6 -P 10 -o /local/home/sarahgw/WGS/SNPS/All_mylu/genolike/All_mylu_gl_filt

# %%
~/angsd/angsd/misc/NGSadmix -likes /local/home/sarahgw/WGS/SNPS/All_mylu/genolike/All_mylu_gl_filt.beagle.gz -K 7 -P 10 -o /local/home/sarahgw/WGS/SNPS/All_mylu/genolike/All_mylu_gl_filt_admix7.1

# %%
~/angsd/angsd/misc/NGSadmix -likes /local/home/sarahgw/WGS/SNPS/All_mylu/genolike/All_mylu_gl_filt.beagle.gz -K 8 -P 10 -o /local/home/sarahgw/WGS/SNPS/All_mylu/genolike/All_mylu_gl_filt_admix8.1

# %%
~/angsd/angsd/misc/NGSadmix -likes /local/home/sarahgw/WGS/SNPS/All_mylu/genolike/All_mylu_gl_filt.beagle.gz -K 5 -P 10 -o /local/home/sarahgw/WGS/SNPS/All_mylu/genolike/All_mylu_gl_filt_admix5.1

# %%
~/angsd/angsd/misc/NGSadmix -likes /local/home/sarahgw/WGS/SNPS/All_mylu/genolike/All_mylu_myse_gl_filt.beagle.gz -K 2 -P 10 -o /local/home/sarahgw/WGS/SNPS/All_mylu/genolike/All_mylu_myse_gl_filt_admix

# %%
pops = as.data.frame(pops)

# %% [markdown]
# # this is with alpha=0. tried admix_auto which is supposed to find optimal alpha value. So gave 100 as the top value....try with higher values? not sure how long it will take.
#
# # need to make delineations between "populations"

# %%
pops
# Out:
#   [1] "Hibernia_Post" "Hibernia_Post" "Hibernia_Post" "Hibernia_Post"
#   [5] "Hibernia_Post" "Hibernia_Post" "Hibernia_Post" "Hibernia_Post"
#   [9] "Hibernia_Post" "Hibernia_Post" "Hibernia_Post" "Hibernia_Post"
#  [13] "Hibernia_Post" "Hibernia_Post" "Hibernia_Post" "Hibernia_Post"
#  [17] "Hibernia_Post" "Hibernia_Post" "Hibernia_Post" "Hibernia_Post"
#  [21] "Hibernia_Post" "Hibernia_Post" "Hibernia_Pre"  "Hibernia_Pre"
#  [25] "Hibernia_Pre"  "Hibernia_Pre"  "Hibernia_Pre"  "Hibernia_Pre"
#  [29] "Hibernia_Pre"  "Hibernia_Pre"  "Hibernia_Pre"  "Hibernia_Pre"
#  [33] "Hibernia_Pre"  "Hibernia_Pre"  "Hibernia_Pre"  "Hibernia_Pre"
#  [37] "Hibernia_Pre"  "Hibernia_Pre"  "Hibernia_Pre"  "Hibernia_Pre"
#  [41] "Hibernia_Pre"  "Hibernia_Pre"  "Williams_Post" "Williams_Post"
#  [45] "Williams_Post" "Williams_Post" "Williams_Post" "Williams_Post"
#  [49] "Williams_Post" "Williams_Post" "Williams_Post" "Williams_Post"
# ...

# %%
admix = (read.table("/local/home/sarahgw/WGS/SNPS/All_mylu/genolike/All_mylu_gl_filt_alph.K2.a100.0.qopt"))

# %%
admix$Site=pops

# %%
rownames(admix)
# Out:
#      [,1]          [,2]          [,3]          [,4]          [,5]
# pops Hibernia_Post Hibernia_Post Hibernia_Post Hibernia_Post Hibernia_Post
#      [,6]          [,7]          [,8]          [,9]          [,10]
# pops Hibernia_Post Hibernia_Post Hibernia_Post Hibernia_Post Hibernia_Post
#      [,11] [,12]       [,13]       [,14]       [,15]       [,16]
# pops ⋯     Greeley_Pre Greeley_Pre Greeley_Pre Greeley_Pre Greeley_Pre
#      [,17]       [,18]       [,19]       [,20]       [,21]
# pops Greeley_Pre Greeley_Pre Greeley_Pre Greeley_Pre Greeley_Pre

# %%
head(admix)
# Out:
#    Hibernia_Post Hibernia_Post Hibernia_Post Hibernia_Post Hibernia_Post
# V1 0.93792730    0.9621168     0.94825610    0.96089256    0.94876130
# V2 0.06207269    0.0378832     0.05174392    0.03910748    0.05123867
#    Hibernia_Post Hibernia_Post Hibernia_Post Hibernia_Post Hibernia_Post ⋯
# V1 0.97630690    0.96072590    0.95339423    0.95786470    0.95752776    ⋯
# V2 0.02369304    0.03927409    0.04660578    0.04213528    0.04247226    ⋯
#    Greeley_Pre Greeley_Pre Greeley_Pre Greeley_Pre Greeley_Pre Greeley_Pre
# V1 0.94941140  0.96809685  0.95136110  0.9537474   0.95849160  0.95035166
# V2 0.05058859  0.03190314  0.04863891  0.0462526   0.04150837  0.04964835
#    Greeley_Pre Greeley_Pre Greeley_Pre Greeley_Pre
# V1 0.94985280  0.95835470  0.95980810  0.95578563
# V2 0.05014718  0.04164528  0.04019185  0.04421437

# %%
Hibernia_post=admix[admix$Site=="Hibernia_Post",]
Hibernia_pre=admix[admix$Site=="Hibernia_Pre",]
Williams_pre=admix[admix$Site=="Williams_Pre",]
Williams_post=admix[admix$Site=="Williams_Post",]
Aeolus_post=admix[admix$Site=="Aeolus_Post",]
Greeley_pre=admix[admix$Site=="Greeley_Pre",]

# %%
pdf("/local/home/sarahgw/WGS/SNPS/All_mylu/plots/admix_plot.pdf", width = 6, height = 6)
par(mfrow=c(2,3))
barplot(as.matrix(t(Hibernia_post[1:2])), main="Hibernia Post",cex.main=1.8, cex.lab=1.7, cex.axis=1.5, col=c("cornsilk", "darkgoldenrod"), beside=FALSE, xlab="Individuals",ylab="admixture", space=0, border=NA)
barplot(as.matrix(t(Hibernia_pre[1:2])), main="Hibernia Pre", cex.main=1.8, cex.lab=1.7, cex.axis=1.5, col=c("cornsilk", "darkgoldenrod"), beside=FALSE, xlab="Individuals",ylab="admixture", space=0, border=NA)
barplot(as.matrix(t(Williams_pre[1:2])), main="Williams Pre",cex.main=1.8, cex.lab=1.7, cex.axis=1.5, col=c("cornsilk", "darkgoldenrod"), beside=FALSE, xlab="Individuals",ylab="admixture", space=0, border=NA)
barplot(as.matrix(t(Williams_post[1:2])), main="Williams Post", cex.main=1.8,cex.lab=1.7, cex.axis=1.5, col=c("cornsilk", "darkgoldenrod"), beside=FALSE, xlab="Individuals",ylab="admixture", space=0, border=NA)
barplot(as.matrix(t(Greeley_pre[1:2])), main="Greeley Pre", cex.main=1.8,cex.lab=1.7, cex.axis=1.5, col=c("cornsilk", "darkgoldenrod"), beside=FALSE, xlab="Individuals",ylab="admixture", space=0, border=NA)
barplot(as.matrix(t(Aeolus_post[1:2])),main="Aeolus Post", cex.main=1.8,cex.lab=1.7, cex.axis=1.5, col=c("cornsilk", "darkgoldenrod"), beside=FALSE, xlab="Individuals",ylab="admixture", space=0, border=NA)

dev.off()
# Out:
# png
#   2

# %%
options(repr.plot.width=6, repr.plot.height=6)

par(mfrow=c(2,3))
barplot(as.matrix(t(Hibernia_post[1:2])), main="Hibernia Post",cex.main=1.8, cex.lab=1.7, cex.axis=1.5, col=c("cornsilk", "darkgoldenrod"), beside=FALSE, xlab="Individuals",ylab="admixture", space=0, border=NA)
barplot(as.matrix(t(Hibernia_pre[1:2])), main="Hibernia Pre", cex.main=1.8, cex.lab=1.7, cex.axis=1.5, col=c("cornsilk", "darkgoldenrod"), beside=FALSE, xlab="Individuals",ylab="admixture", space=0, border=NA)
barplot(as.matrix(t(Williams_pre[1:2])), main="Williams Pre",cex.main=1.8, cex.lab=1.7, cex.axis=1.5, col=c("cornsilk", "darkgoldenrod"), beside=FALSE, xlab="Individuals",ylab="admixture", space=0, border=NA)
barplot(as.matrix(t(Williams_post[1:2])), main="Williams Post", cex.main=1.8,cex.lab=1.7, cex.axis=1.5, col=c("cornsilk", "darkgoldenrod"), beside=FALSE, xlab="Individuals",ylab="admixture", space=0, border=NA)
barplot(as.matrix(t(Greeley_pre[1:2])), main="Greeley Pre", cex.main=1.8,cex.lab=1.7, cex.axis=1.5, col=c("cornsilk", "darkgoldenrod"), beside=FALSE, xlab="Individuals",ylab="admixture", space=0, border=NA)
barplot(as.matrix(t(Aeolus_post[1:2])),main="Aeolus Post", cex.main=1.8,cex.lab=1.7, cex.axis=1.5, col=c("cornsilk", "darkgoldenrod"), beside=FALSE, xlab="Individuals",ylab="admixture", space=0, border=NA)
# Out:
# Plot with title “Aeolus Post”

# %%
admix = t(as.matrix(read.table("/local/home/sarahgw/WGS/SNPS/All_mylu/genolike/All_mylu_gl_filt_admix4.qopt")))
#admix = admix[,order(pops[,1])]
#pops = pops[order(pops[,1]),]
h = barplot(admix,col=1:4,space=0,border=NA,xlab="Individuals",ylab="admixture")
text(tapply(1:nrow(pops),pops[,1],mean),-0.05,unique(pops[,1]),xpd=T)
# Out:
# plot without title

# %%
admix = t(as.matrix(read.table("/local/home/sarahgw/WGS/SNPS/All_mylu/genolike/All_mylu_gl_filt_admix3.qopt")))
#admix = admix[,order(pops[,1])]
#pops = pops[order(pops[,1]),]
h = barplot(admix,col=1:3,space=0,border=NA,xlab="Individuals",ylab="admixture")
text(tapply(1:nrow(pops),pops[,1],mean),-0.05,unique(pops[,1]),xpd=T)
# Out:
# plot without title

# %%
admix = t(as.matrix(read.table("/local/home/sarahgw/WGS/SNPS/All_mylu/genolike/All_mylu_gl_filt_admix2.qopt")))
#admix = admix[,order(pops[,1])]
#pops = pops[order(pops[,1]),]
h = barplot(admix,col=1:2,space=0,border=NA,xlab="Individuals",ylab="admixture")
text(tapply(1:nrow(pops),pops[,1],mean),-0.05,unique(pops[,1]),xpd=T)
# Out:
# plot without title

# %%
admix = t(as.matrix(read.table("/local/home/sarahgw/WGS/SNPS/All_mylu/genolike/All_mylu_gl_filt_admix4.2.qopt")))
#admix = admix[,order(pops[,1])]
#pops = pops[order(pops[,1]),]
h = barplot(admix,col=c("coral1", "cornsilk", "darkgoldenrod", "burlywood3", "darkgoldenrod1", "brown", "coral4"),space=0,border=NA,xlab="Individuals",ylab="admixture")
text(tapply(1:nrow(pops),pops[,1],mean),-0.05,unique(pops[,1]),xpd=T, cex=0.85)
# Out:
# plot without title

# %%
# Out:
# Error in !head: invalid argument type
# Traceback:

# %%
setwd("/local/home/sarahgw/WGS/SNPS/All_mylu/genolike/")
samples=read.table("/local/home/sarahgw/WGS/Sequences/filelists/All_Mylu_Myse.filelist", header=FALSE)

# %%
samples1=gsub("_pairedplus_marked_dupes.bam", " ", samples$V1)

# %%
samples1
# Out:
#   [1] "NJ_U_04 " "NJ_U_14 " "VT_U_05 " "VT_U_03 " "NJ_E_01 " "NJ_E_02 "
#   [7] "NJ_E_04 " "NJ_E_23 " "NJ_E_24 " "NJ_E_25 " "NJ_E_26 " "NJ_E_28 "
#  [13] "NJ_E_29 " "NJ_E_30 " "NJ_E_05 " "NJ_E_06 " "NJ_E_07 " "NJ_E_08 "
#  [19] "NJ_E_10 " "NJ_E_22 " "NJ_E_13 " "NJ_E_14 " "NJ_E_15 " "NJ_E_16 "
#  [25] "NJ_E_18 " "NJ_E_21 " "NJ_U_01 " "NJ_U_02 " "NJ_U_03 " "NJ_U_05 "
#  [31] "NJ_U_06 " "NJ_U_08 " "NJ_U_09 " "NJ_U_10 " "NJ_U_11 " "NJ_U_12 "
#  [37] "NJ_U_15 " "NJ_U_16 " "NJ_U_21 " "NJ_U_22 " "NJ_U_23 " "NJ_U_25 "
#  [43] "NJ_U_07 " "NJ_U_17 " "NJ_U_18 " "NJ_U_19 " "NY_E_15 " "NY_E_16 "
#  [49] "NY_E_17 " "NY_E_18 " "NY_E_27 " "NY_E_28 " "NY_E_29 " "NY_E_30 "
#  [55] "NY_E_19 " "NY_E_21 " "NY_E_22 " "NY_E_23 " "NY_E_25 " "NY_E_03 "
#  [61] "NY_E_04 " "NY_E_05 " "NY_E_06 " "NY_E_07 " "NY_E_08 " "NY_E_09 "
#  [67] "NY_E_10 " "NY_U_10 " "NY_U_11 " "NY_U_12 " "NY_U_14 " "NY_U_15 "
#  [73] "NY_U_16 " "NY_U_18 " "NY_U_19 " "NY_U_21 " "NY_U_23 " "NY_U_25 "
# ...

# %%
pops=rep(c("Myse", "NJE","NJU", "NYE", "NYU", "VTE", "VTU"), times=c(4, 22, 20, 21, 22, 27, 20))
pops=as.data.frame(pops)

# %%
admix = t(as.matrix(read.table("/local/home/sarahgw/WGS/SNPS/All_mylu/genolike/All_mylu_myse_gl_filt_admix.qopt")))
#admix = admix[,order(pops[,1])]
#pops = pops[order(pops[,1]),]
h = barplot(admix,col=1:2,space=0,border=NA,xlab="Individuals",ylab="admixture")
text(tapply(1:nrow(pops),pops[,1],mean),-0.05,unique(pops[,1]),xpd=T)
# Out:
# plot without title

# %%
admixmyse=admix[,c(1, 2,  3, 4)]
admixmyse
# Out:
#    [,1]  [,2]  [,3]  [,4]
# V1 1e-09 1e-09 1e-09 1e-09
# V2 1e+00 1e+00 1e+00 1e+00

# %%
h = barplot(admixmyse,col=1:2,space=0,border=NA,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
admixoutliers=admix[,c(40, 41,  68, 74, 128, 134)]
admixoutliers
# Out:
#    [,1]       [,2]       [,3]       [,4]       [,5]  [,6]
# V1 0.98480227 0.98203763 0.94678423 0.95476379 1e+00 0.98293344
# V2 0.01519773 0.01796237 0.05321577 0.04523621 1e-09 0.01706656

# %%
h = barplot(admixoutliers,col=1:2,space=0,border=NA,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
samples1= as.data.frame(samples1)
samples1$Pos=1:NROW(samples1)
print(samples1)
# Out:
#     samples1 Pos
# 1   NJ_E_01    1
# 2   NJ_E_02    2
# 3   NJ_E_04    3
# 4   NJ_E_23    4
# 5   NJ_E_24    5
# 6   NJ_E_25    6
# 7   NJ_E_26    7
# 8   NJ_E_28    8
# 9   NJ_E_29    9
# 10  NJ_E_30   10
# 11  NJ_E_05   11
# 12  NJ_E_06   12
# 13  NJ_E_07   13
# 14  NJ_E_08   14
# 15  NJ_E_10   15
# 16  NJ_E_22   16
# 17  NJ_E_13   17
# 18  NJ_E_14   18
# 19  NJ_E_15   19
# 20  NJ_E_16   20
# 21  NJ_E_18   21
# 22  NJ_E_21   22
# 23  NJ_U_01   23
# 24  NJ_U_02   24
# 25  NJ_U_03   25
# 26  NJ_U_05   26
# 27  NJ_U_06   27
# 28  NJ_U_08   28
# 29  NJ_U_09   29
# 30  NJ_U_10   30
# 31  NJ_U_11   31
# 32  NJ_U_12   32
# 33  NJ_U_15   33
# 34  NJ_U_16   34
# 35  NJ_U_21   35
# 36  NJ_U_22   36
# 37  NJ_U_23   37
# 38  NJ_U_25   38
# 39  NJ_U_07   39
# 40  NJ_U_17   40
# 41  NJ_U_18   41
# 42  NJ_U_19   42
# 43  NY_E_15   43
# 44  NY_E_16   44
# 45  NY_E_17   45
# 46  NY_E_18   46
# 47  NY_E_27   47
# 48  NY_E_28   48
# 49  NY_E_29   49
# 50  NY_E_30   50
# 51  NY_E_19   51
# ...

# %%
Other outliers: 
VTU26 124
VTU33 130
NYU10 64
NYU18 70
NJU22 36
NJU23 37

# %%
admixoutliers=admix[,c(36, 37,  64, 70, 124, 130)]
admixoutliers
# Out:
#    [,1]         [,2]         [,3]  [,4]  [,5]  [,6]
# V1 1.488778e-08 1.505054e-06 1e+00 1e+00 1e+00 1e+00
# V2 6.483466e-01 6.453991e-01 1e-09 1e-09 1e-09 1e-09
# V3 3.516534e-01 3.545994e-01 1e-09 1e-09 1e-09 1e-09

# %%
h = barplot(admixoutliers,col=1:6,space=0,border=NA,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
h = barplot(admixoutliers,col=1:4,space=0,border=NA,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
h = barplot(admixoutliers,col=1:3,space=0,border=NA,xlab="Individuals",ylab="admixture")
# Out:
# plot without title

# %%
pops
# Out:
#   [1] NJE NJE NJE NJE NJE NJE NJE NJE NJE NJE NJE NJE NJE NJE NJE NJE NJE NJE
#  [19] NJE NJE NJE NJE NJU NJU NJU NJU NJU NJU NJU NJU NJU NJU NJU NJU NJU NJU
#  [37] NJU NJU NJU NJU NJU NJU NYE NYE NYE NYE NYE NYE NYE NYE NYE NYE NYE NYE
#  [55] NYE NYE NYE NYE NYE NYE NYE NYE NYE NYU NYU NYU NYU NYU NYU NYU NYU NYU
#  [73] NYU NYU NYU NYU NYU NYU NYU NYU NYU NYU NYU NYU NYU VTE VTE VTE VTE VTE
#  [91] VTE VTE VTE VTE VTE VTE VTE VTE VTE VTE VTE VTE VTE VTE VTE VTE VTE VTE
# [109] VTE VTE VTE VTE VTU VTU VTU VTU VTU VTU VTU VTU VTU VTU VTU VTU VTU VTU
# [127] VTU VTU VTU VTU VTU VTU
# Levels: NJE NJU NYE NYU VTE VTU

# %%
samples[1]
# Out:
#     V1
# 1   NJ_E_01_pairedplus_marked_dupes.bam
# 2   NJ_E_02_pairedplus_marked_dupes.bam
# 3   NJ_E_04_pairedplus_marked_dupes.bam
# 4   NJ_E_23_pairedplus_marked_dupes.bam
# 5   NJ_E_24_pairedplus_marked_dupes.bam
# 6   NJ_E_25_pairedplus_marked_dupes.bam
# 7   NJ_E_26_pairedplus_marked_dupes.bam
# 8   NJ_E_28_pairedplus_marked_dupes.bam
# 9   NJ_E_29_pairedplus_marked_dupes.bam
# 10  NJ_E_30_pairedplus_marked_dupes.bam
# 11  NJ_E_05_pairedplus_marked_dupes.bam
# 12  NJ_E_06_pairedplus_marked_dupes.bam
# 13  NJ_E_07_pairedplus_marked_dupes.bam
# 14  NJ_E_08_pairedplus_marked_dupes.bam
# 15  NJ_E_10_pairedplus_marked_dupes.bam
# 16  NJ_E_22_pairedplus_marked_dupes.bam
# 17  NJ_E_13_pairedplus_marked_dupes.bam
# 18  NJ_E_14_pairedplus_marked_dupes.bam
# 19  NJ_E_15_pairedplus_marked_dupes.bam
# 20  NJ_E_16_pairedplus_marked_dupes.bam
# 21  NJ_E_18_pairedplus_marked_dupes.bam
# 22  NJ_E_21_pairedplus_marked_dupes.bam
# 23  NJ_U_01_pairedplus_marked_dupes.bam
# ...

# %%
NROW(m)
# Out:
# [1] 100

# %%
library(ggplot2)
library(ggmap)
library(maps)
library(mapdata)
library(ggsn)

# %%
d=data.frame(lat= c(41.878459, 40.942720, 43.745522, 43.233111), lon= c(-74.194664, -74.492896, -72.764975, -73.057238), 
             Site=c("Williams", "Hibernia", "Aeolus", "Greeley"), 
             lablat= c(42.1, 40.9, 43.238316, 44), lablon= c( -74.162368, -75.8, -74, -72.8))
state_labs=data.frame(lat= c(43.278459, 39.67, 44.545522), 
                      lon= c(-75.594664, -74.88, -72.764975), State=c("New York", "New \n Jersey", "Vermont"))

states = map_data("state")
sites = subset(states, region %in% c("new hampshire", "pennsylvania", "maryland", "delaware", "rhode island","connecticut", "massachusetts", "new york", "new jersey", "vermont"))
print(ggplot() + 
  geom_polygon(data = sites, aes(x=long, y = lat, group = group), fill = "grey94", color = "black") + 
  coord_fixed(1.3)  + theme_bw() + geom_point(data=d, aes(x=lon, y=lat, color=Site),size=3,)
      + geom_text(data=d, aes(x=lablon, y=lablat, label=Site),size=4)
      + geom_text(data=state_labs, aes(x=lon, y=lat, label=State),size=2.7,fontface="italic")
    + scale_color_manual(values=c("cyan3","darkcyan",  "cornflowerblue", "darkblue")) + theme( panel.grid.minor = element_blank(), panel.grid.major = element_blank()))
# Out:
# plot without title

# %%
      
ggsave("/data/sarahgw/WGS/SNPS/All_mylu/plots/Map.pdf")
# Out:
# Saving 6.67 x 6.67 in image

# %%
p=ggplot() + 
geom_polygon(data = sites, aes(x=long, y = lat, group = group), fill = "lightgrey", color = "black") + 
coord_fixed(1.3) + theme_bw() + geom_point(data=d, aes(x=lon, y=lat, color=Site),size=3,) + 
geom_text(data=d, aes(x=lablon, y=lablat, label=Site),size=2.9) +
geom_text(data=state_labs, aes(x=lon, y=lat, label=State),size=2.9,fontface="italic")+ 
scale_color_manual(values=c("cyan3","darkcyan",  "cornflowerblue", "darkblue")) + theme( panel.grid.minor = element_blank(), panel.grid.major = element_blank())

# %%
usa <- map_data("usa") # we already did this, but we can do it again
ggplot() + geom_polygon(data = usa, aes(x=long, y = lat, group = group)) + 
  coord_fixed(1.3)

ggplot() + 
  geom_polygon(data = usa, aes(x=long, y = lat, group = group), fill = NA, color = "red") + 
  coord_fixed(1.3)
states <- map_data("state")
bay <- subset(states, region %in% c("maryland", "virginia", "delaware"))
ggplot() + 
  geom_polygon(data = bay, aes(x=long, y = lat, group = group), fill = "gray", color = "black") + 
  coord_fixed(1.3) + coord_fixed(xlim = c(-78, -75),  ylim = c(36.5, 39.5), ratio = 1.3) + theme_get()
# Out:
# plot without title
# plot without title
# plot without title
