# %%
setwd("/local/home/sarahgw/WGS/SNPS/All_mylu/genolike/")
samples=read.table("/local/home/sarahgw/WGS/Sequences/filelists/All_Mylu.filelist", header=FALSE)

# %%
print(samples)
# Out:
#                                      V1
# 1   NJ_E_01_pairedplus_marked_dupes.bam
# 2   NJ_E_02_pairedplus_marked_dupes.bam
# 3   NJ_E_04_pairedplus_marked_dupes.bam
# 4   NJ_E_23_pairedplus_marked_dupes.bam
# 5   NJ_E_24_pairedplus_marked_dupes.bam
# 6   NJ_E_25_pairedplus_marked_dupes.bam
# 7   NJ_E_26_pairedplus_marked_dupes.bam
# 8   NJ_E_28_pairedplus_marked_dupes.bam
# 9   NJ_E_29_pairedplus_marked_dupes.bam
# 10  NJ_E_30_pairedplus_marked_dupes.bam
# 11  NJ_E_05_pairedplus_marked_dupes.bam
# 12  NJ_E_06_pairedplus_marked_dupes.bam
# 13  NJ_E_07_pairedplus_marked_dupes.bam
# 14  NJ_E_08_pairedplus_marked_dupes.bam
# 15  NJ_E_10_pairedplus_marked_dupes.bam
# 16  NJ_E_22_pairedplus_marked_dupes.bam
# 17  NJ_E_13_pairedplus_marked_dupes.bam
# 18  NJ_E_14_pairedplus_marked_dupes.bam
# 19  NJ_E_15_pairedplus_marked_dupes.bam
# 20  NJ_E_16_pairedplus_marked_dupes.bam
# 21  NJ_E_18_pairedplus_marked_dupes.bam
# 22  NJ_E_21_pairedplus_marked_dupes.bam
# 23  NJ_U_01_pairedplus_marked_dupes.bam
# 24  NJ_U_02_pairedplus_marked_dupes.bam
# 25  NJ_U_03_pairedplus_marked_dupes.bam
# 26  NJ_U_05_pairedplus_marked_dupes.bam
# 27  NJ_U_06_pairedplus_marked_dupes.bam
# 28  NJ_U_08_pairedplus_marked_dupes.bam
# 29  NJ_U_09_pairedplus_marked_dupes.bam
# 30  NJ_U_10_pairedplus_marked_dupes.bam
# 31  NJ_U_11_pairedplus_marked_dupes.bam
# 32  NJ_U_12_pairedplus_marked_dupes.bam
# 33  NJ_U_15_pairedplus_marked_dupes.bam
# 34  NJ_U_16_pairedplus_marked_dupes.bam
# 35  NJ_U_21_pairedplus_marked_dupes.bam
# 36  NJ_U_22_pairedplus_marked_dupes.bam
# 37  NJ_U_23_pairedplus_marked_dupes.bam
# 38  NJ_U_25_pairedplus_marked_dupes.bam
# 39  NJ_U_07_pairedplus_marked_dupes.bam
# 40  NJ_U_17_pairedplus_marked_dupes.bam
# 41  NJ_U_18_pairedplus_marked_dupes.bam
# 42  NJ_U_19_pairedplus_marked_dupes.bam
# 43  NY_E_15_pairedplus_marked_dupes.bam
# 44  NY_E_16_pairedplus_marked_dupes.bam
# 45  NY_E_17_pairedplus_marked_dupes.bam
# 46  NY_E_18_pairedplus_marked_dupes.bam
# 47  NY_E_27_pairedplus_marked_dupes.bam
# 48  NY_E_28_pairedplus_marked_dupes.bam
# 49  NY_E_29_pairedplus_marked_dupes.bam
# 50  NY_E_30_pairedplus_marked_dupes.bam
# 51  NY_E_19_pairedplus_marked_dupes.bam
# 52  NY_E_21_pairedplus_marked_dupes.bam
# 53  NY_E_22_pairedplus_marked_dupes.bam
# 54  NY_E_23_pairedplus_marked_dupes.bam
# 55  NY_E_25_pairedplus_marked_dupes.bam
# 56  NY_E_03_pairedplus_marked_dupes.bam
# 57  NY_E_04_pairedplus_marked_dupes.bam
# 58  NY_E_05_pairedplus_marked_dupes.bam
# 59  NY_E_06_pairedplus_marked_dupes.bam
# 60  NY_E_07_pairedplus_marked_dupes.bam
# 127 VT_U_15_pairedplus_marked_dupes.bam
# 128 VT_U_17_pairedplus_marked_dupes.bam
# 129 VT_U_19_pairedplus_marked_dupes.bam
# 130 VT_U_33_pairedplus_marked_dupes.bam
# 131 VT_U_37_pairedplus_marked_dupes.bam
# 132 VT_U_40_pairedplus_marked_dupes.bam

# %%
pops=rep(c("red","dark red", "blue", "dark blue", "green", "dark green"), times=c(22, 20, 21, 22, 27, 20))

# %%
pops
# Out:
#   [1] "red"        "red"        "red"        "red"        "red"
#   [6] "red"        "red"        "red"        "red"        "red"
#  [11] "red"        "red"        "red"        "red"        "red"
#  [16] "red"        "red"        "red"        "red"        "red"
#  [21] "red"        "red"        "dark red"   "dark red"   "dark red"
#  [26] "dark red"   "dark red"   "dark red"   "dark red"   "dark red"
#  [31] "dark red"   "dark red"   "dark red"   "dark red"   "dark red"
#  [36] "dark red"   "dark red"   "dark red"   "dark red"   "dark red"
#  [41] "dark red"   "dark red"   "blue"       "blue"       "blue"
#  [46] "blue"       "blue"       "blue"       "blue"       "blue"
#  [51] "blue"       "blue"       "blue"       "blue"       "blue"
#  [56] "blue"       "blue"       "blue"       "blue"       "blue"
#  [61] "blue"       "blue"       "blue"       "dark blue"  "dark blue"
#  [66] "dark blue"  "dark blue"  "dark blue"  "dark blue"  "dark blue"
#  [71] "dark blue"  "dark blue"  "dark blue"  "dark blue"  "dark blue"
#  [76] "dark blue"  "dark blue"  "dark blue"  "dark blue"  "dark blue"
#  [81] "dark blue"  "dark blue"  "dark blue"  "dark blue"  "dark blue"
#  [86] "green"      "green"      "green"      "green"      "green"
#  [91] "green"      "green"      "green"      "green"      "green"
#  [96] "green"      "green"      "green"      "green"      "green"
# [101] "green"      "green"      "green"      "green"      "green"
# [106] "green"      "green"      "green"      "green"      "green"
# [111] "green"      "green"      "dark green" "dark green" "dark green"
# [116] "dark green" "dark green" "dark green" "dark green" "dark green"
# [121] "dark green" "dark green" "dark green" "dark green" "dark green"
# [126] "dark green" "dark green" "dark green" "dark green" "dark green"
# [131] "dark green" "dark green"

# %%
U
NJ60
NY66
VT60


E
66
63
81

# %%
name <- "All_mylu_gl_filt.cov"
m <- as.matrix(read.table(name))
e <- eigen(m)
plot(e$vectors[,1:2],lwd=2,ylab="PC 2",xlab="PC 2",main="Principal components",col=pops)
# Out:
# Plot with title “Principal components”

# %%
NROW(m)
# Out:
# [1] 100

# %%
options(jupyter.log_level = 2L)

# %%
# Out:
# function (name, pos = -1L, envir = as.environment(pos), all.names = FALSE,
#     pattern, sorted = TRUE)
# {
#     if (!missing(name)) {
#         pos <- tryCatch(name, error = function(e) e)
#         if (inherits(pos, "error")) {
#             name <- substitute(name)
#             if (!is.character(name))
#                 name <- deparse(name)
#             warning(gettextf("%s converted to character string",
#                 sQuote(name)), domain = NA)
#             pos <- name
#         }
#     }
#     all.names <- .Internal(ls(envir, all.names, sorted))
#     if (!missing(pattern)) {
#         if ((ll <- length(grep("[", pattern, fixed = TRUE))) &&
#             ll != length(grep("]", pattern, fixed = TRUE))) {
#             if (pattern == "[") {
#                 pattern <- "\\\\["
#                 warning("replaced regular expression pattern '[' by  '\\\\\\\\['")
#             }
#             else if (length(grep("[^\\\\\\\\]\\\\[<-", pattern))) {
#                 pattern <- sub("\\\\[<-", "\\\\\\\\\\\\[<-", pattern)
#                 warning("replaced '[<-' by '\\\\\\\\[<-' in regular expression pattern")
#             }
#         }
#         grep(pattern, all.names, value = TRUE)
#     }
#     else all.names
# }
# <bytecode: 0x18eedb0>
# <environment: namespace:base>
