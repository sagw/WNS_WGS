# %%
setwd("~/WGS/SNPS/All_mylu/genoprob/")

# %%
ibsmat=read.table("All_mylu.ibsMat")

# %%
NCOL(ibsmat)
NROW(ibsmat)
# Out:
# [1] 132
# [1] 132

# %%
head(name)
# Out:
# [1] "All_mylu.covMat"

# %%
name <- "All_mylu.ibsMat"
m <- as.matrix(read.table(name))
mds <- cmdscale(as.dist(m))
plot(mds,lwd=2,ylab="Dist",xlab="Dist",main="multidimensional scaling",col=rep(1:3,each=10))
# Out:
# Plot with title “multidimensional scaling”

# %%
name <- "All_mylu.covMat"
m <- as.matrix(read.table(name))
e <- eigen(m)
plot(e$vectors[,1:2],lwd=2,ylab="PC 2",xlab="PC 2",main="Principal components",col=rep(1:3,each=10),pch=16)
# Out:
# Plot with title “Principal components”
